# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('FINAL.csv')
df
# Out:
#      Soil_color  Nitrogen  Phosphorus  Potassium   pH  Rainfall  Temperature  \
# 0         Black        75          50        100  6.5      1000           20
# 1         Black        80          50        100  6.5      1000           20
# 2         Black        85          50        100  6.5      1000           20
# 3         Black        90          50        100  6.5      1000           20
# 4         Black        95          50        100  6.5      1000           20
# ...         ...       ...         ...        ...  ...       ...          ...
# 4508      Black       130          80        150  7.0      1400           30
# 4509      Black       135          80        150  7.0      1400           30
# 4510      Black       140          80        150  7.0      1400           30
# 4511      Black       145          80        150  7.0      1400           30
# 4512      Black       150          80        150  7.0      1400           30
#
#            Crop Fertilizer
# ...

# %%
df.head()
# Out:
#   Soil_color  Nitrogen  Phosphorus  Potassium   pH  Rainfall  Temperature  \
# 0      Black        75          50        100  6.5      1000           20
# 1      Black        80          50        100  6.5      1000           20
# 2      Black        85          50        100  6.5      1000           20
# 3      Black        90          50        100  6.5      1000           20
# 4      Black        95          50        100  6.5      1000           20
#
#         Crop Fertilizer
# 0  Sugarcane       Urea
# 1  Sugarcane       Urea
# 2  Sugarcane       Urea
# 3  Sugarcane       Urea
# 4  Sugarcane       Urea

# %%
df.tail()
# Out:
#      Soil_color  Nitrogen  Phosphorus  Potassium   pH  Rainfall  Temperature  \
# 4508      Black       130          80        150  7.0      1400           30
# 4509      Black       135          80        150  7.0      1400           30
# 4510      Black       140          80        150  7.0      1400           30
# 4511      Black       145          80        150  7.0      1400           30
# 4512      Black       150          80        150  7.0      1400           30
#
#            Crop Fertilizer
# 4508  Sugarcane        MOP
# 4509  Sugarcane        MOP
# 4510  Sugarcane        MOP
# 4511  Sugarcane        MOP
# 4512  Sugarcane        MOP

# %%
df.describe()
# Out:
#           Nitrogen   Phosphorus    Potassium           pH     Rainfall  \
# count  4513.000000  4513.000000  4513.000000  4513.000000  4513.000000
# mean     95.409927    54.341901    63.595170     6.715267   819.189010
# std      38.060648    16.551991    35.691911     0.625198   251.730813
# min      20.000000    10.000000     5.000000     5.500000   300.000000
# 25%      60.000000    40.000000    40.000000     6.000000   600.000000
# 50%     105.000000    55.000000    55.000000     6.500000   800.000000
# 75%     125.000000    65.000000    75.000000     7.000000  1000.000000
# max     150.000000    90.000000   150.000000     8.500000  1700.000000
#
#        Temperature
# count  4513.000000
# mean     25.915134
# std       5.897328
# min      10.000000
# 25%      20.000000
# 50%      25.000000
# 75%      30.000000
# max      40.000000

# %%
df.isnull().sum()
#does not contain any missing values
# Out:
# Soil_color     0
# Nitrogen       0
# Phosphorus     0
# Potassium      0
# pH             0
# Rainfall       0
# Temperature    0
# Crop           0
# Fertilizer     0
# dtype: int64

# %%
df.size
# Out:
# 40617

# %%
df.shape
# Out:
# (4513, 9)

# %%
df.columns
# Out:
# Index(['Soil_color', 'Nitrogen', 'Phosphorus', 'Potassium', 'pH', 'Rainfall',
#        'Temperature', 'Crop', 'Fertilizer'],
#       dtype='object')

# %%
df['Crop'].unique()
# Out:
# array(['Sugarcane', 'Jowar', 'Cotton', 'Rice', 'Wheat', 'Groundnut',
#        'Maize', 'Tur', 'Urad', 'Moong', 'Gram', 'Masoor', 'Soybean',
#        'Ginger', 'Turmeric', 'Grapes'], dtype=object)

# %% [markdown]
# # Data Visualization

# %%
# Histogram of Temperature
plt.figure(figsize=(8, 6))
sns.histplot(data=df_crop, x='Temperature', hue='Crop', kde=True)
plt.title('Histogram of Temperature')
plt.xlabel('Temperature')
plt.ylabel('Frequency')
plt.show()
# Out:
# D:\Softwares\Jupiter\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\Softwares\Jupiter\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# D:\Softwares\Jupiter\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
# Histogram of Rainfall
plt.figure(figsize=(8, 6))
sns.histplot(data=df_crop, x='Rainfall', hue='Crop', kde=True)
plt.title('Histogram of Rainfall')
plt.xlabel('Rainfall')
plt.ylabel('Frequency')
plt.show()
# Out:
# D:\Softwares\Jupiter\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\Softwares\Jupiter\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# D:\Softwares\Jupiter\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
# Histogram of pH
plt.figure(figsize=(8, 6))
sns.histplot(data=df_crop, x='pH', hue='Crop', kde=True)
plt.title('Histogram of pH')
plt.xlabel('pH')
plt.ylabel('Frequency')
plt.show()
# Out:
# D:\Softwares\Jupiter\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\Softwares\Jupiter\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# D:\Softwares\Jupiter\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
# Exclude non-numeric columns
numeric_columns = df.select_dtypes(include=['float64', 'int64'])

# Compute correlation matrix
corr_matrix = numeric_columns.corr()
corr_matrix
# Out:
#              Nitrogen  Phosphorus  Potassium        pH  Rainfall  Temperature
# Nitrogen     1.000000    0.709539   0.584315  0.182850  0.269364    -0.010213
# Phosphorus   0.709539    1.000000   0.573970  0.244945  0.225453    -0.055303
# Potassium    0.584315    0.573970   1.000000  0.075110  0.445671     0.053413
# pH           0.182850    0.244945   0.075110  1.000000  0.097884    -0.002949
# Rainfall     0.269364    0.225453   0.445671  0.097884  1.000000     0.315045
# Temperature -0.010213   -0.055303   0.053413 -0.002949  0.315045     1.000000

# %%
# Exclude non-numeric columns
numeric_columns = df.select_dtypes(include=['float64', 'int64'])

# select_dtypes(include=['float64', 'int64']) filters the DataFrame to include only columns with numeric data types (float64 and int64), 
# excluding non-numeric columns such as 'Soil_color', 'Crop', and 'Fertilizer'.


# Compute correlation matrix
corr_matrix = numeric_columns.corr()

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
plt.scatter(df['Rainfall'], df['Crop'])
plt.xlabel('Rainfall')
plt.ylabel('Crop')
plt.title('Scatter Plot: Rainfall vs Crop')
plt.show()

# %%
plt.hist(df['Rainfall'], bins=20)
plt.xlabel('Rainfall')
plt.ylabel('Frequency')
plt.title('Histogram of Rainfall')
plt.show()

# %%
df['Rainfall'].value_counts()
# Out:
# Rainfall
# 900     720
# 800     705
# 1000    657
# 600     607
# 700     567
# 500     533
# 1100    146
# 1200    146
# 400     101
# 1500     93
# 1300     90
# 1400     90
# 300      40
# 1600      9
# 1700      9
# Name: count, dtype: int64

# %%
df['Soil_color'].value_counts()
# Out:
# Soil_color
# Black            2260
# Red               744
# Dark Brown        659
# Red               480
# Reddish Brown     265
# Light Brown        54
# Medium Brown       51
# Name: count, dtype: int64

# %%
sns.boxplot(x='Crop', y='pH', data=df)
plt.title('Boxplot of Temperature by Crop')
plt.xticks(rotation=45)
plt.show()

# %%
df['Crop'].value_counts()
# Out:
# Crop
# Sugarcane    1010
# Wheat         859
# Cotton        650
# Jowar         394
# Maize         350
# Rice          309
# Groundnut     177
# Tur           126
# Ginger        125
# Grapes        125
# Urad           99
# Moong          99
# Gram           78
# Turmeric       55
# Soybean        45
# Masoor         12
# Name: count, dtype: int64

# %%
sns.countplot(x='Crop', data=df)
plt.title('Count of Crops')
plt.xticks(rotation=45)
plt.show()

# %%
sns.violinplot(x='Fertilizer', y='pH', data=df)
plt.title('Violin Plot: Fertilizer vs Nitrogen')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Outlier Removal

# %%
import numpy as np
import pandas as pd

# Assuming 'FINAL.csv' is the name of your crop recommendation dataset file
df_crop = pd.read_csv('FINAL.csv')

# Display the first few rows of the DataFrame
print(df_crop.head())
# Out:
#   Soil_color  Nitrogen  Phosphorus  Potassium   pH  Rainfall  Temperature  \
# 0      Black        75          50        100  6.5      1000           20
# 1      Black        80          50        100  6.5      1000           20
# 2      Black        85          50        100  6.5      1000           20
# 3      Black        90          50        100  6.5      1000           20
# 4      Black        95          50        100  6.5      1000           20
#
#         Crop Fertilizer
# 0  Sugarcane       Urea
# 1  Sugarcane       Urea
# 2  Sugarcane       Urea
# 3  Sugarcane       Urea
# 4  Sugarcane       Urea

# %%
def removal_box_plot(df, column, threshold):
    sns.boxplot(df[column])
    plt.title(f'Original Box Plot of {column}')
    plt.show()

    removed_outliers = df[df[column] <= threshold]

    sns.boxplot(removed_outliers[column])
    plt.title(f'Box Plot without Outliers of {column}')
    plt.show()
    
    return removed_outliers

threshold_value = 1500

no_outliers = removal_box_plot(df_crop, 'Rainfall', threshold_value)

# %%
#outlier removal with IQR Method for Rainfall

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def removal_box_plot(df, column):
    sns.boxplot(df[column])
    plt.title(f'Original Box Plot of {column}')
    plt.show()

    # Calculate the first quartile (Q1), third quartile (Q3), and IQR
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    
    # Define the lower and upper bounds for outlier detection
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Remove outliers
    removed_outliers = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]

    sns.boxplot(removed_outliers[column])
    plt.title(f'Box Plot without Outliers of {column}')
    plt.show()
    
    return removed_outliers

no_outliers = removal_box_plot(df, 'Rainfall')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def removal_box_plot(df, column, threshold):
    sns.boxplot(df[column])
    plt.title(f'Original Box Plot of {column}')
    plt.show()

    removed_outliers = df[df[column] <= threshold]

    sns.boxplot(removed_outliers[column])
    plt.title(f'Box Plot without Outliers of {column}')
    plt.show()
    
    return removed_outliers

threshold_value = 8.9

no_outliers = removal_box_plot(df_crop, 'pH', threshold_value)

# %%
#outlier removal with IQR Method for pH

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def removal_box_plot(df, column):
    sns.boxplot(df[column])
    plt.title(f'Original Box Plot of {column}')
    plt.show()

    # Calculate the first quartile (Q1) and third quartile (Q3)
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    
    # Calculate the IQR
    IQR = Q3 - Q1
    
    # Define the lower and upper bounds for outlier detection
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Remove outliers
    removed_outliers = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]

    sns.boxplot(removed_outliers[column])
    plt.title(f'Box Plot without Outliers of {column}')
    plt.show()
    
    return removed_outliers

no_outliers = removal_box_plot(df, 'pH')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def removal_box_plot(df, columns, threshold):
    for column in columns:
        # Original box plot
        sns.boxplot(df[column])
        plt.title(f'Original Box Plot of {column}')
        plt.show()

        # Removing outliers
        df = df[df[column] <= threshold]

        # Box plot after removing outliers
        sns.boxplot(df[column])
        plt.title(f'Box Plot without Outliers of {column}')
        plt.show()

    return df

threshold_value = 100
columns_to_remove_outliers = ['Nitrogen', 'Phosphorus', 'Potassium']  # Example columns

# Assuming 'df_crop' is your DataFrame containing the crop recommendation data
no_outliers_df = removal_box_plot(df_crop, columns_to_remove_outliers, threshold_value)

# %%
#outlier removal with IQR Method for Temperature

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Function to remove outliers using IQR method
def remove_outliers_iqr(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df_no_outliers = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
    return df_no_outliers

# Box plot for Temperature before removing outliers
plt.figure(figsize=(8, 6))
sns.boxplot(x=df_crop['Temperature'])
plt.title('Box Plot for Temperature (Before Removing Outliers)')
plt.xlabel('Temperature')
plt.show()

# Remove outliers for Temperature
df_no_outliers = remove_outliers_iqr(df_crop, 'Temperature')

# Box plot for Temperature after removing outliers
plt.figure(figsize=(8, 6))
sns.boxplot(x=df_no_outliers['Temperature'])
plt.title('Box Plot for Temperature (After Removing Outliers)')
plt.xlabel('Temperature')
plt.show()

# %%
#outlier removal with IQR Method for all parameters

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def removal_box_plot(df, column, threshold):
    sns.boxplot(df[column])
    plt.title(f'Original Box Plot of {column}')
    plt.show()

    removed_outliers = df[df[column] <= threshold]

    sns.boxplot(removed_outliers[column])
    plt.title(f'Box Plot without Outliers of {column}')
    plt.show()
    
    return removed_outliers

# Outlier removal for Rainfall
threshold_value = 1500
no_outliers = removal_box_plot(df_crop, 'Rainfall', threshold_value)

# Outlier removal for pH
threshold_value = 8.9
no_outliers = removal_box_plot(df_crop, 'pH', threshold_value)

# Outlier removal for Nitrogen, Phosphorus, and Potassium
def removal_box_plot_multiple(df, columns, threshold):
    for column in columns:
        sns.boxplot(df[column])
        plt.title(f'Original Box Plot of {column}')
        plt.show()

        df = df[df[column] <= threshold]

        sns.boxplot(df[column])
        plt.title(f'Box Plot without Outliers of {column}')
        plt.show()

    return df

threshold_value = 100
columns_to_remove_outliers = ['Nitrogen', 'Phosphorus', 'Potassium']
no_outliers_df = removal_box_plot_multiple(df_crop, columns_to_remove_outliers, threshold_value)

import seaborn as sns
import matplotlib.pyplot as plt

# Function to remove outliers using IQR method
def remove_outliers_iqr(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df_no_outliers = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
    return df_no_outliers

# Box plot for Temperature before removing outliers
plt.figure(figsize=(8, 6))
sns.boxplot(x=df_crop['Temperature'])
plt.title('Box Plot for Temperature (Before Removing Outliers)')
plt.xlabel('Temperature')
plt.show()

# Remove outliers for Temperature
df_no_outliers = remove_outliers_iqr(df_crop, 'Temperature')

# Box plot for Temperature after removing outliers
plt.figure(figsize=(8, 6))
sns.boxplot(x=df_no_outliers['Temperature'])
plt.title('Box Plot for Temperature (After Removing Outliers)')
plt.xlabel('Temperature')
plt.show()

# %% [markdown]
# # Data Preprocessing

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Load the dataset from a CSV file
df = pd.read_csv('FINAL.csv')

# Print the first few rows of the DataFrame to understand its structure
print("Original DataFrame:")
print(df.head())

# Clean the 'Soil_color' column
df['Soil_color'] = df['Soil_color'].str.strip()  # Remove leading/trailing spaces
df['Soil_color'] = df['Soil_color'].str.lower()  # Convert to lowercase

# Print unique values in 'Soil_color' after cleaning
print("\nUnique 'Soil_color' values after cleaning:")
print(df['Soil_color'].unique())

# Function to remove outliers using a threshold value
def removal_box_plot(df, column, threshold):
    removed_outliers = df[df[column] <= threshold]
    return removed_outliers

# Outlier removal for Rainfall and pH
df = removal_box_plot(df, 'Rainfall', 1500)
df = removal_box_plot(df, 'pH', 8.9)

# Function to remove outliers using a threshold value for multiple columns
def removal_box_plot_multiple(df, columns, threshold):
    for column in columns:
        df = df[df[column] <= threshold]
    return df

# Outlier removal for Nitrogen, Phosphorus, and Potassium
columns_to_remove_outliers = ['Nitrogen', 'Phosphorus', 'Potassium']
df = removal_box_plot_multiple(df, columns_to_remove_outliers, 100)

# Function to remove outliers using IQR method
def remove_outliers_iqr(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df_no_outliers = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
    return df_no_outliers

# Remove outliers for Temperature
df = remove_outliers_iqr(df, 'Temperature')

# Define the input features (X) and target variable (y) after outlier removal
X = df[['Temperature', 'Rainfall', 'Soil_color', 'pH', 'Nitrogen', 'Phosphorus', 'Potassium', 'Fertilizer']]
y = df['Crop']

# Columns to impute
columns_to_impute = ['Temperature', 'Rainfall', 'pH', 'Nitrogen', 'Phosphorus', 'Potassium']

# Handle missing values in numerical columns
imputer = SimpleImputer(strategy='mean')
X[columns_to_impute] = imputer.fit_transform(X[columns_to_impute])

# Encode categorical variables (Soil_color, Fertilizer)
encoder = OneHotEncoder(drop='first', sparse_output=False)  # Use sparse_output instead of sparse
X_encoded = pd.get_dummies(X, columns=['Soil_color', 'Fertilizer'], drop_first=True)

# Scale numerical features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_encoded)

# Save the preprocessed data to new variables for later use
X_preprocessed = X_scaled
y_preprocessed = y
# Out:
# Original DataFrame:
#   Soil_color  Nitrogen  Phosphorus  Potassium   pH  Rainfall  Temperature  \
# 0      Black        75          50        100  6.5      1000           20
# 1      Black        80          50        100  6.5      1000           20
# 2      Black        85          50        100  6.5      1000           20
# 3      Black        90          50        100  6.5      1000           20
# 4      Black        95          50        100  6.5      1000           20
#
#         Crop Fertilizer
# 0  Sugarcane       Urea
# 1  Sugarcane       Urea
# 2  Sugarcane       Urea
# 3  Sugarcane       Urea
# 4  Sugarcane       Urea
#
# Unique 'Soil_color' values after cleaning:
# ['black' 'red' 'medium brown' 'dark brown' 'light brown' 'reddish brown']
# C:\Users\shrey\AppData\Local\Temp\ipykernel_15332\473293756.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# # Implementation of ML model

# %% [markdown]
# # 1st ML Model :- Random Forest

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import pandas as pd

# Assuming X_preprocessed and y_preprocessed are already defined from the preprocessing step

# Split the preprocessed features and target variable into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_preprocessed, y_preprocessed, test_size=0.2, random_state=42)

# Train a Random Forest Classifier
model = RandomForestClassifier(random_state=42)

# Evaluate the model using cross-validation
cv_scores = cross_val_score(model, X_train, y_train, cv=5, scoring='accuracy')

# Print the cross-validation scores
print("Cross-Validation Scores:", cv_scores)
print("Mean Cross-Validation Accuracy:", cv_scores.mean())

# Fit the model on the entire training data
model.fit(X_train, y_train)

# Evaluate accuracy on the training data
y_train_pred = model.predict(X_train)
train_accuracy = accuracy_score(y_train, y_train_pred)
print("Training Accuracy:", train_accuracy * 100)

# Evaluate accuracy on the testing data
y_test_pred = model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_test_pred)
print("Testing Accuracy:", test_accuracy * 100)

# Feature importance analysis
importances = model.feature_importances_
feature_names = pd.get_dummies(X, columns=['Soil_color', 'Fertilizer'], drop_first=True).columns

# Create a DataFrame for better visualization
feature_importances = pd.DataFrame({'feature': feature_names, 'importance': importances})
feature_importances = feature_importances.sort_values(by='importance', ascending=False)
print(feature_importances)

# Plot feature importances
plt.figure(figsize=(10, 6))
plt.barh(feature_importances['feature'], feature_importances['importance'])
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Feature Importances')
plt.gca().invert_yaxis()
plt.show()
# Out:
# Cross-Validation Scores: [0.990625 0.98125  0.984375 0.9875   0.9875  ]
# Mean Cross-Validation Accuracy: 0.9862499999999998
# Training Accuracy: 100.0
# Testing Accuracy: 99.5
#                               feature  importance
# 5                           Potassium    0.141679
# 3                            Nitrogen    0.138373
# 1                            Rainfall    0.135647
# 4                          Phosphorus    0.082186
# 0                         Temperature    0.073277
# 14            Fertilizer_19:19:19 NPK    0.062605
# 2                                  pH    0.048929
# 9                      Soil_color_red    0.045291
# 18  Fertilizer_Chilated Micronutrient    0.044507
# 6               Soil_color_dark brown    0.040057
# 19                     Fertilizer_DAP    0.029689
# 25                    Fertilizer_Urea    0.027711
# 8             Soil_color_medium brown    0.019086
# 10           Soil_color_reddish brown    0.019052
# ...

# %%
# Manual Predictions

# %%
import pandas as pd

# Assume user_inputs is a dictionary containing input parameters
user_inputs = {'Temperature': 30, 'Rainfall': 800,'Soil_color': 'Black', 'pH': 7 }

# Create a DataFrame with the user input
input_data = pd.DataFrame([user_inputs])

# Ensure consistent column names and order
input_data = input_data[['Temperature','Rainfall','Soil_color','pH']]

# Handle missing values in numerical columns
input_data.loc[:, columns_to_impute] = imputer.transform(input_data.loc[:, columns_to_impute])

# Encode categorical variables (Soil_color)
input_data_encoded = pd.get_dummies(input_data, columns=['Soil_color'], drop_first=True)

# Add missing dummy columns that were present during training
missing_columns = set(X_encoded.columns) - set(input_data_encoded.columns)
for col in missing_columns:
    input_data_encoded[col] = 0  # Add missing column with all zeros

# Reorder columns to match the order during training
input_data_encoded = input_data_encoded[X_encoded.columns]

# Scale the input data using the same scaler used for training
input_data_scaled = scaler.transform(input_data_encoded)

# Use the Random Forest Classifier to predict 'Crop'
predicted_label_class = model.predict(input_data_scaled)

# Display the predicted label
print("Predicted Crop Label:", predicted_label_class[0])
# Out:
# Predicted Crop Label: Jowar

# %%
import pandas as pd

# Assume user_inputs is a dictionary containing input parameters
user_inputs = {'Temperature': 25, 'Rainfall': 800, 'Soil_color': 'Red', 'pH': 7.5}

# Create a DataFrame with the user input
input_data = pd.DataFrame([user_inputs])

# Ensure consistent column names and order
input_data = input_data[['Temperature', 'Rainfall', 'Soil_color', 'pH']]

# Handle missing values in numerical columns
input_data.loc[:, columns_to_impute] = imputer.transform(input_data.loc[:, columns_to_impute])

# Encode categorical variables (Soil_color)
input_data_encoded = pd.get_dummies(input_data, columns=['Soil_color'], drop_first=True)

# Add missing dummy columns that were present during training
missing_columns = set(X_encoded.columns) - set(input_data_encoded.columns)
for col in missing_columns:
    input_data_encoded[col] = 0  # Add missing column with all zeros

# Reorder columns to match the order during training
input_data_encoded = input_data_encoded[X_encoded.columns]

# Scale the input data using the same scaler used for training
input_data_scaled = scaler.transform(input_data_encoded)

# Use the Random Forest Classifier to predict 'Crop'
predicted_label_class = model.predict(input_data_scaled)

# Display the predicted label
print("Predicted Crop Label:", predicted_label_class[0])
# Out:
# Predicted Crop Label: Jowar

# %%
# Hyperparameter tuning (fINAL cODE)

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# Load and preprocess the dataset
df = pd.read_csv('FINAL.csv')

# Clean the 'Soil_color' column
df['Soil_color'] = df['Soil_color'].str.strip().str.lower()

# Define the input features (X) and target variable (y)
X = df[['Temperature', 'Rainfall', 'Soil_color', 'pH', 'Nitrogen', 'Phosphorus', 'Potassium', 'Fertilizer']]
y = df['Crop']

# Columns to impute
columns_to_impute = ['Temperature', 'Rainfall', 'pH', 'Nitrogen', 'Phosphorus', 'Potassium']

# Handle missing values in numerical columns
imputer = SimpleImputer(strategy='mean')
X[columns_to_impute] = imputer.fit_transform(X[columns_to_impute])

# Encode categorical variables (Soil_color, Fertilizer)
encoder = OneHotEncoder(drop='first', sparse_output=False)
X_encoded = pd.get_dummies(X, columns=['Soil_color', 'Fertilizer'], drop_first=True)

# Scale numerical features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_encoded)

# Encode the target variable
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Split the preprocessed features and target variable into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_encoded, test_size=0.2, random_state=42)

# Hyperparameter tuning using GridSearchCV
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

rf = RandomForestClassifier(random_state=42)
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=5, n_jobs=-1, scoring='accuracy')
grid_search.fit(X_train, y_train)

# Best parameters and best score
best_params = grid_search.best_params_
best_score = grid_search.best_score_
print("Best Parameters:", best_params)
print("Best Cross-Validation Accuracy:", best_score)

# Train the Random Forest Classifier with the best parameters
best_model = grid_search.best_estimator_
best_model.fit(X_train, y_train)

# Evaluate accuracy on the training data
y_train_pred = best_model.predict(X_train)
train_accuracy = accuracy_score(y_train, y_train_pred)
print("Training Accuracy:", train_accuracy * 100)

# Evaluate accuracy on the testing data
y_test_pred = best_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_test_pred)
print("Testing Accuracy:", test_accuracy * 100)

# Feature importance analysis
importances = best_model.feature_importances_
feature_names = pd.get_dummies(X, columns=['Soil_color', 'Fertilizer'], drop_first=True).columns

# Create a DataFrame for better visualization
feature_importances = pd.DataFrame({'feature': feature_names, 'importance': importances})
feature_importances = feature_importances.sort_values(by='importance', ascending=False)
# Out:
# C:\Users\shrey\AppData\Local\Temp\ipykernel_15332\28621248.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[columns_to_impute] = imputer.fit_transform(X[columns_to_impute])
# Best Parameters: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# Best Cross-Validation Accuracy: 0.9914127423822716
# Training Accuracy: 100.0
# Testing Accuracy: 100.0

# %%
from sklearn.metrics import classification_report

# Accuracy
print("Accuracy:",test_accuracy)

# Classification Report
print("\nClassification Report:")
print(classification_report(y_test, y_test_pred))
# Out:
# Accuracy: 0.995
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Cotton       1.00      1.00      1.00        18
#       Ginger       1.00      1.00      1.00        19
#         Gram       1.00      1.00      1.00        12
#    Groundnut       1.00      1.00      1.00        42
#        Jowar       1.00      0.98      0.99        88
#       Masoor       1.00      1.00      1.00         3
#        Moong       0.96      1.00      0.98        23
#         Rice       1.00      1.00      1.00        28
#      Soybean       1.00      1.00      1.00         5
#          Tur       1.00      1.00      1.00        26
#     Turmeric       1.00      1.00      1.00         8
#         Urad       0.95      1.00      0.97        18
#        Wheat       1.00      1.00      1.00       110
#
#     accuracy                           0.99       400
#    macro avg       0.99      1.00      1.00       400
# ...

# %%
from sklearn.metrics import confusion_matrix

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, y_test_pred)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('Actual Labels')
plt.show()

# %% [markdown]
# # 2nd ML Model:- Ensemble learning Method = 'Voting' and ML model used  = 'Randomforest and GradientBoostingClassifier'

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, VotingClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# Assuming your dataset is already cleaned and loaded as df

# Clean the 'Soil_color' column
df['Soil_color'] = df['Soil_color'].str.strip().str.lower()

# Define the input features (X) and target variable (y)
X = df[['Temperature', 'Rainfall', 'Soil_color', 'pH', 'Nitrogen', 'Phosphorus', 'Potassium', 'Fertilizer']]
y = df['Crop']

# Columns to impute
columns_to_impute = ['Temperature', 'Rainfall', 'pH', 'Nitrogen', 'Phosphorus', 'Potassium']

# Handle missing values in numerical columns
imputer = SimpleImputer(strategy='mean')
X[columns_to_impute] = imputer.fit_transform(X[columns_to_impute])

# Encode categorical variables (Soil_color, Fertilizer)
encoder = OneHotEncoder(drop='first', sparse_output=False)
X_encoded = pd.get_dummies(X, columns=['Soil_color', 'Fertilizer'], drop_first=True)

# Scale numerical features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_encoded)

# Encode the target variable
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Split the preprocessed features and target variable into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_encoded, test_size=0.2, random_state=42)

# Define individual classifiers
rf_classifier = RandomForestClassifier(random_state=42)
gb_classifier = GradientBoostingClassifier(random_state=42)

# Create an ensemble model using VotingClassifier
ensemble_model = VotingClassifier(estimators=[
    ('rf', rf_classifier),
    ('gb', gb_classifier)
], voting='hard')

# Evaluate the ensemble model using cross-validation
cv_scores = cross_val_score(ensemble_model, X_train, y_train, cv=5, scoring='accuracy')

# Print the cross-validation scores
print("Cross-Validation Scores:", cv_scores)
print("Mean Cross-Validation Accuracy:", cv_scores.mean())

# Fit the ensemble model on the entire training data
ensemble_model.fit(X_train, y_train)

# Evaluate accuracy on the training data
y_train_pred = ensemble_model.predict(X_train)
train_accuracy = accuracy_score(y_train, y_train_pred)
print("Training Accuracy:", train_accuracy * 100)

# Evaluate accuracy on the testing data
y_test_pred = ensemble_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_test_pred)
print("Testing Accuracy:", test_accuracy * 100)

# Feature importance analysis for RandomForestClassifier
# Assuming RandomForestClassifier is more interpretable for feature importances
importances = rf_classifier.fit(X_train, y_train).feature_importances_
feature_names = pd.get_dummies(X, columns=['Soil_color', 'Fertilizer'], drop_first=True).columns

# Create a DataFrame for better visualization
feature_importances = pd.DataFrame({'feature': feature_names, 'importance': importances})
feature_importances = feature_importances.sort_values(by='importance', ascending=False)
# Out:
# C:\Users\shrey\AppData\Local\Temp\ipykernel_15332\1271944935.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[columns_to_impute] = imputer.fit_transform(X[columns_to_impute])
# Cross-Validation Scores: [0.990625 0.975    0.978125 0.984375 0.9875  ]
# Mean Cross-Validation Accuracy: 0.983125
# Training Accuracy: 100.0
# Testing Accuracy: 99.25

# %%
from sklearn.metrics import classification_report

# Accuracy
print("Accuracy:",test_accuracy*100)

# Classification Report
print("\nClassification Report:")
print(classification_report(y_test, y_test_pred))
# Out:
# Accuracy: 99.25
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        18
#            1       0.95      1.00      0.97        19
#            2       1.00      1.00      1.00        12
#            3       1.00      1.00      1.00        42
#            4       0.99      0.99      0.99        88
#            5       1.00      1.00      1.00         3
#            6       0.96      0.96      0.96        23
#            7       1.00      1.00      1.00        28
#            8       1.00      1.00      1.00         5
#           10       1.00      1.00      1.00        26
#           11       1.00      1.00      1.00         8
#           12       1.00      1.00      1.00        18
#           13       1.00      0.99      1.00       110
#
#     accuracy                           0.99       400
#    macro avg       0.99      1.00      0.99       400
# ...

# %%
from sklearn.metrics import confusion_matrix

# Accuracy
print("Accuracy:",test_accuracy*100)

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, y_test_pred)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('Actual Labels')
plt.show()
# Out:
# Accuracy: 99.25

# %% [markdown]
# # 3rd ML Model :- Support Vector Machine ML model

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report
import matplotlib.pyplot as plt
import pandas as pd

# Assuming X_preprocessed and y_preprocessed are already defined from the preprocessing step

# Split the preprocessed features and target variable into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_preprocessed, y_preprocessed, test_size=0.2, random_state=42)

# Train an SVM Classifier
model = SVC(random_state=42)

# Evaluate the model using cross-validation
cv_scores = cross_val_score(model, X_train, y_train, cv=5, scoring='accuracy')

# Print the cross-validation scores
print("Cross-Validation Scores:", cv_scores)
print("Mean Cross-Validation Accuracy:", cv_scores.mean())

# Fit the model on the entire training data
model.fit(X_train, y_train)

# Evaluate accuracy on the training data
y_train_pred = model.predict(X_train)
train_accuracy = accuracy_score(y_train, y_train_pred)
print("Training Accuracy:", train_accuracy * 100)

# Evaluate accuracy on the testing data
y_test_pred = model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_test_pred)
print("Testing Accuracy:", test_accuracy * 100)
# Out:
# Cross-Validation Scores: [0.890625 0.88125  0.8875   0.909375 0.915625]
# Mean Cross-Validation Accuracy: 0.896875
# Training Accuracy: 90.875
# Testing Accuracy: 91.25

# %%
from sklearn.metrics import classification_report

# Accuracy
print("Accuracy:",test_accuracy)

# Classification Report
print("\nClassification Report:")
print(classification_report(y_test, y_test_pred))
# Out:
# Accuracy: 0.9125
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Cotton       1.00      1.00      1.00        18
#       Ginger       1.00      1.00      1.00        19
#         Gram       0.85      0.92      0.88        12
#    Groundnut       0.92      0.83      0.88        42
#        Jowar       0.80      0.98      0.88        88
#       Masoor       1.00      0.33      0.50         3
#        Moong       1.00      0.70      0.82        23
#         Rice       0.93      1.00      0.97        28
#      Soybean       1.00      0.80      0.89         5
#          Tur       0.86      0.92      0.89        26
#     Turmeric       1.00      0.62      0.77         8
#         Urad       0.73      0.44      0.55        18
#        Wheat       1.00      1.00      1.00       110
#
#     accuracy                           0.91       400
#    macro avg       0.93      0.81      0.85       400
# ...

# %%
from sklearn.metrics import confusion_matrix

# Accuracy
print("Accuracy:",test_accuracy)

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, y_test_pred)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('Actual Labels')
plt.show()
# Out:
# Accuracy: 0.9125

# %% [markdown]
# # 4th ML Model KNearest Neighbours ML model

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report
import matplotlib.pyplot as plt
import pandas as pd

# Assuming X_preprocessed and y_preprocessed are already defined from the preprocessing step

# Split the preprocessed features and target variable into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_preprocessed, y_preprocessed, test_size=0.2, random_state=42)

# Set the value of k
k = 7
model = KNeighborsClassifier(n_neighbors=k)

# Evaluate the model using cross-validation
cv_scores = cross_val_score(model, X_train, y_train, cv=5, scoring='accuracy')

# Print the cross-validation scores
print("Cross-Validation Scores:", cv_scores)
print("Mean Cross-Validation Accuracy:", cv_scores.mean())

# Fit the model on the entire training data
model.fit(X_train, y_train)

# Evaluate accuracy on the training data
y_train_pred = model.predict(X_train)
train_accuracy = accuracy_score(y_train, y_train_pred)
print("Training Accuracy:", train_accuracy * 100)

# Evaluate accuracy on the testing data
y_test_pred = model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_test_pred)
print("Testing Accuracy:", test_accuracy * 100)
# Out:
# Cross-Validation Scores: [0.884375 0.865625 0.90625  0.878125 0.884375]
# Mean Cross-Validation Accuracy: 0.88375
# Training Accuracy: 95.9375
# Testing Accuracy: 94.25

# %%
from sklearn.metrics import classification_report

# Accuracy
print("Accuracy:",test_accuracy*100)

# Classification Report
print("\nClassification Report:")
print(classification_report(y_test, y_test_pred))
# Out:
# Accuracy: 94.25
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Cotton       1.00      1.00      1.00        18
#       Ginger       1.00      1.00      1.00        19
#         Gram       0.83      0.83      0.83        12
#    Groundnut       0.91      0.93      0.92        42
#        Jowar       0.92      0.94      0.93        88
#       Masoor       1.00      0.67      0.80         3
#        Moong       0.87      0.87      0.87        23
#         Rice       0.96      0.96      0.96        28
#      Soybean       0.71      1.00      0.83         5
#          Tur       0.93      0.96      0.94        26
#     Turmeric       1.00      0.75      0.86         8
#         Urad       0.87      0.72      0.79        18
#        Wheat       1.00      1.00      1.00       110
#
#     accuracy                           0.94       400
#    macro avg       0.92      0.90      0.90       400
# ...

# %%
from sklearn.metrics import confusion_matrix

# Accuracy
print("Accuracy:",test_accuracy*100)

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, y_test_pred)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Greens', cbar=False)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('Actual Labels')
plt.show()
# Out:
# Accuracy: 94.25

# %% [markdown]
# # XG Boost

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score, classification_report
import matplotlib.pyplot as plt
import xgboost as xgb

# Assuming your dataset is already cleaned and loaded as df

# Clean the 'Soil_color' column
df['Soil_color'] = df['Soil_color'].str.strip().str.lower()

# Define the input features (X) and target variable (y)
X = df[['Temperature', 'Rainfall', 'Soil_color', 'pH', 'Nitrogen', 'Phosphorus', 'Potassium', 'Fertilizer']]
y = df['Crop']

# Columns to impute
columns_to_impute = ['Temperature', 'Rainfall', 'pH', 'Nitrogen', 'Phosphorus', 'Potassium']

# Handle missing values in numerical columns
imputer = SimpleImputer(strategy='mean')
X[columns_to_impute] = imputer.fit_transform(X[columns_to_impute])

# Encode categorical variables (Soil_color, Fertilizer)
encoder = OneHotEncoder(drop='first', sparse_output=False)
X_encoded = pd.get_dummies(X, columns=['Soil_color', 'Fertilizer'], drop_first=True)

# Scale numerical features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_encoded)

# Encode the target variable
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Split the preprocessed features and target variable into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_encoded, test_size=0.2, random_state=42)

# Train an XGBoost Classifier
model = xgb.XGBClassifier(random_state=42)

# Evaluate the model using cross-validation
cv_scores = cross_val_score(model, X_train, y_train, cv=5, scoring='accuracy')

# Print the cross-validation scores
print("Cross-Validation Scores:", cv_scores)
print("Mean Cross-Validation Accuracy:", cv_scores.mean())

# Fit the model on the entire training data
model.fit(X_train, y_train)

# Evaluate accuracy on the training data
y_train_pred = model.predict(X_train)
train_accuracy = accuracy_score(y_train, y_train_pred)
print("Training Accuracy:", train_accuracy * 100)

# Evaluate accuracy on the testing data
y_test_pred = model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_test_pred)
print("Testing Accuracy:", test_accuracy * 100)
# Out:
# C:\Users\shrey\AppData\Local\Temp\ipykernel_15332\2151815700.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[columns_to_impute] = imputer.fit_transform(X[columns_to_impute])
# Cross-Validation Scores: [0.996875 0.978125 0.9875   0.984375 0.996875]
# Mean Cross-Validation Accuracy: 0.9887500000000001
# Training Accuracy: 100.0
# Testing Accuracy: 99.75

# %%
from sklearn.metrics import classification_report

# Accuracy
print("Accuracy:",test_accuracy*100)

# Classification Report
print("\nClassification Report:")
print(classification_report(y_test, y_test_pred))
# Out:
# Accuracy: 99.75
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        18
#            1       0.95      1.00      0.97        19
#            2       1.00      1.00      1.00        12
#            3       1.00      1.00      1.00        42
#            4       1.00      1.00      1.00        88
#            5       1.00      1.00      1.00         3
#            6       1.00      1.00      1.00        23
#            7       1.00      1.00      1.00        28
#            8       1.00      1.00      1.00         5
#           10       1.00      1.00      1.00        26
#           11       1.00      1.00      1.00         8
#           12       1.00      1.00      1.00        18
#           13       1.00      0.99      1.00       110
#
#     accuracy                           1.00       400
#    macro avg       1.00      1.00      1.00       400
# ...

# %%
from sklearn.metrics import confusion_matrix

# Accuracy
print("Accuracy:",test_accuracy*100)

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, y_test_pred)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Reds', cbar=False)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('Actual Labels')
plt.show()
# Out:
# Accuracy: 99.75

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Accuracy scores of the saved models
accuracies = [99.75, 94.25, 91.25, 99.25, 100.0]

# Names of the models
models = ['XGBoost', 'KNN', 'SVM', 'RandomForest+GradientBoosting', 'Random Forest']

# Plotting
plt.figure(figsize=[10,5],dpi=100)
plt.title('Accuracy Comparison for Crop Recommendation')
plt.xlabel('Accuracy')
plt.ylabel('Algorithm')
sns.barplot(x=accuracies, y=models, palette='dark')
plt.show()
# Out:
# D:\Softwares\Jupiter\Lib\site-packages\seaborn\_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Accuracy scores of the saved models
accuracies = [99.75, 94.25, 91.25, 99.25, 100.0]

# Names of the models
models = ['XGBoost', 'KNN', 'SVM', 'RandomForest+GradientBoosting', 'Random Forest']

# Creating a DataFrame for better handling in Seaborn
import pandas as pd

data = pd.DataFrame({
    'Model': models,
    'Accuracy': accuracies
})

# Plotting
plt.figure(figsize=[10, 5], dpi=100)
plt.title('Accuracy Comparison for Crop Recommendation')
plt.xlabel('Algorithm')
plt.ylabel('Accuracy')
sns.pointplot(x='Accuracy', y='Model', data=data, join=True, markers='o', linestyles='--', color='blue')
plt.show()

# %%
import matplotlib.pyplot as plt

# Accuracy scores of the saved models
accuracies = [99.75, 94.25, 91.25, 99.25, 100.0]

# Names of the models
models = ['XGBoost', 'KNN', 'SVM', 'RandomForest+GradientBoosting', 'Random Forest']

# Plotting
plt.figure(figsize=[10, 5], dpi=100)
plt.bar(models, accuracies, color='skyblue')
plt.title('Accuracy Comparison for Crop Recommendation')
plt.xlabel('Algorithm')
plt.ylabel('Accuracy')
plt.ylim(0, 105)  # Setting the y-axis limit for better visualization
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %%
# Accuracy scores of the saved models
accuracies = [0.8665835411471322, 0.8541147132169576, 0.8092269326683291, 0.85785536159601, 0.8690773067331671]

# Names of the models
models = ['XGBoost', 'KNN', 'SVM', 'RandomForest+GradientBoosting', 'Random Forest']

# Plotting the histogram
plt.figure(figsize=(10, 6))
plt.bar(models, accuracies, color='skyblue')
plt.xlabel('Models')
plt.ylabel('Accuracy')
plt.title('Accuracy Comparison for Crop Recommendation')
plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility
plt.grid(axis='y')  # Add gridlines on y-axis
plt.show()

# %%
import matplotlib.pyplot as plt

# Accuracy scores of the saved models
accuracies = [99.75, 94.25, 91.25, 99.25, 100.0]

# Names of the models
models = ['XGBoost', 'KNN', 'SVM', 'RandomForest+GradientBoosting', 'Random Forest']

# Plotting
plt.figure(figsize=[10, 5], dpi=100)
plt.scatter(models, accuracies, color='blue')
plt.title('Accuracy Comparison for Crop Recommendation')
plt.xlabel('Algorithm')
plt.ylabel('Accuracy')
plt.ylim(0, 105)  # Setting the y-axis limit for better visualization
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(True)  # Add grid for better readability
plt.show()

# %%
#KDE PLOT
import matplotlib.pyplot as plt
import seaborn as sns

# Accuracy scores of the saved models
accuracies = [99.75, 94.25, 91.25, 99.25, 100.0]

# Creating a KDE plot
plt.figure(figsize=[10, 5], dpi=100)
sns.kdeplot(accuracies, shade=True, color='blue')
plt.title('KDE Plot for Model Accuracies')
plt.xlabel('Accuracy')
plt.ylabel('Density')
plt.grid(True)  # Add grid for better readability
plt.show()
# Out:
# C:\Users\shrey\AppData\Local\Temp\ipykernel_15332\1052184058.py:10: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(accuracies, shade=True, color='blue')
# D:\Softwares\Jupiter\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#KDE PLOT

import seaborn as sns
import matplotlib.pyplot as plt

# Accuracy scores of the saved models
accuracies = [0.8665835411471322, 0.8541147132169576, 0.8092269326683291, 0.85785536159601, 0.8690773067331671]

# Names of the models
models = ['XGBoost', 'KNN', 'SVM', 'RandomForest+GradientBoosting', 'Random Forest']

# KDE plot
plt.figure(figsize=(10, 6))
sns.kdeplot(accuracies, shade=True, color='blue')
plt.title('Accuracy KDE Plot')
plt.xlabel('Accuracy')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\shrey\AppData\Local\Temp\ipykernel_1148\1564963892.py:12: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(accuracies, shade=True, color='blue')
# D:\Softwares\Jupiter\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Accuracy scores of the saved models
accuracies = [99.75, 94.25, 91.25, 99.25, 100.0]

# Names of the models
models = ['XGBoost', 'KNN', 'SVM', 'RandomForest+GradientBoosting', 'Random Forest']

# Plotting
plt.figure(figsize=[10,5],dpi=100)
plt.title('Accuracy Comparison for Crop Recommendation')
plt.xlabel('Accuracy')
plt.ylabel('Algorithm')
sns.barplot(x=accuracies, y=models, palette='dark')

# Annotating bars with precise accuracy values
for i, acc in enumerate(accuracies):
    plt.text(acc, i, f'{acc:.2f}%', ha='left', va='center')

plt.show()
# Out:
# D:\Softwares\Jupiter\Lib\site-packages\seaborn\_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)
